# %% [markdown]
# # time series forecasting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv('df1.csv')

# %% [markdown]
# # ARIMA model

# %%
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
    train_size = int(len(X) * 0.70)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]

    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit(disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
        #print('predicted=%f, expected=%f' % (yhat, test[t]))
    
    error = mean_squared_error(test, predictions)
    return error

# %%
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                print('order', order)
                try:
                    mse = evaluate_arima_model(dataset, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    #print('ARIMA%s MSE=%.3f' % (order,mse))
                except:
                    continue
    print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# %%
def daily_forecast(df_new, p_values, d_values, q_values, best_order):
    X = df_new.y.astype('float').values
    Xtime = df_new.ds.values
    print('test')
    #best_order = evaluate_models(X, p_values, d_values, q_values)
    #evaluate_models(X, p_values, d_values, q_values)
    print('best order:', best_order)
    train_size = int(len(X) * 0.66)
    train, test = X[0:train_size], X[train_size:]
    traintime, testtime = Xtime[0:train_size], Xtime[train_size:]
    history = [x for x in train]

    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=best_order)
        model_fit = model.fit(disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
        print('predicted=%f, expected=%f, error=%i percentage' % (yhat, test[t], int(abs(yhat - test[t])/test[t]*100)))
        
    #error = mean_squared_error(test, predictions)
    #print('mean squared error', error)
    return train, test, traintime, testtime, predictions

# %%
# parameters
p_values = [5, 7, 9] #[0, 1, 2, 4, 6, 8, 10]
d_values = range(0,3) #range(0, 3)
q_values = range(0,3) #range(0, 3)

# %%
best_order = [7, 0, 1]
train_1, test_1, traintime_1, testtime_1, prediction_1 = daily_forecast(df, p_values, d_values, q_values, best_order)
df = pd.DataFrame(prediction_1)
df.to_csv('forecasting.csv')
# Out:
# test
# best order: [7, 0, 1]
# predicted=35754.182054, expected=37707.000000, error=5 percentage
# predicted=37422.016430, expected=34559.000000, error=8 percentage
# predicted=35462.736925, expected=26883.000000, error=31 percentage
# predicted=30339.965137, expected=26399.000000, error=14 percentage
# predicted=28457.393918, expected=26294.000000, error=8 percentage
# predicted=29132.567915, expected=27389.000000, error=6 percentage
# predicted=30643.410934, expected=28900.000000, error=6 percentage
# predicted=31389.170456, expected=34892.000000, error=10 percentage
# predicted=34361.482209, expected=34887.000000, error=1 percentage
# predicted=35085.282004, expected=27854.000000, error=25 percentage
# predicted=31233.036679, expected=28164.000000, error=10 percentage
# predicted=29645.998483, expected=29774.000000, error=0 percentage
# predicted=30849.711338, expected=45165.000000, error=31 percentage
# predicted=40413.236574, expected=72445.000000, error=44 percentage
# predicted=59050.229512, expected=79293.000000, error=25 percentage
# predicted=67832.349790, expected=89417.000000, error=24 percentage
# predicted=73820.756991, expected=75703.000000, error=2 percentage
# predicted=66804.024008, expected=97419.000000, error=31 percentage
# predicted=77474.171667, expected=105030.000000, error=26 percentage
# predicted=89239.427973, expected=97423.000000, error=8 percentage
# predicted=88447.766760, expected=90344.000000, error=2 percentage
# predicted=81969.101131, expected=85710.000000, error=4 percentage
# predicted=77659.295270, expected=88296.000000, error=12 percentage
# predicted=79086.904604, expected=73348.000000, error=7 percentage
# predicted=73013.825622, expected=78569.000000, error=7 percentage
# predicted=72427.236317, expected=73914.000000, error=2 percentage
# predicted=70324.906403, expected=67226.000000, error=4 percentage
# predicted=65526.629607, expected=47720.000000, error=37 percentage
# predicted=52243.992069, expected=48013.000000, error=8 percentage
# predicted=48043.164919, expected=45521.000000, error=5 percentage
# predicted=46499.370548, expected=35200.000000, error=32 percentage
# predicted=41124.337090, expected=31656.000000, error=29 percentage
# predicted=35864.242295, expected=30298.000000, error=18 percentage
# predicted=33651.611950, expected=30679.000000, error=9 percentage
# predicted=33126.117422, expected=32552.000000, error=1 percentage
# predicted=34827.533836, expected=42229.000000, error=17 percentage
# predicted=40141.493573, expected=41070.000000, error=2 percentage
# predicted=41020.406197, expected=29879.000000, error=37 percentage
# predicted=33950.770195, expected=29194.000000, error=16 percentage
# predicted=30773.587006, expected=28616.000000, error=7 percentage
# predicted=30596.363600, expected=28891.000000, error=5 percentage
# predicted=31573.165023, expected=31568.000000, error=0 percentage
# predicted=33587.402429, expected=130545.000000, error=74 percentage
# predicted=91662.741487, expected=39600.000000, error=131 percentage
# predicted=61196.342515, expected=33622.000000, error=82 percentage
# predicted=37606.283426, expected=27667.000000, error=35 percentage
# predicted=28080.723235, expected=27169.000000, error=3 percentage
# predicted=29318.387139, expected=27779.000000, error=5 percentage
# predicted=35744.319667, expected=109915.000000, error=67 percentage
# predicted=73556.687102, expected=37882.000000, error=94 percentage
# predicted=52022.337703, expected=36871.000000, error=41 percentage
# predicted=35652.255357, expected=28352.000000, error=25 percentage
# predicted=27680.341713, expected=27078.000000, error=2 percentage
# predicted=27839.313726, expected=29291.000000, error=4 percentage
# predicted=47956.536687, expected=29727.000000, error=61 percentage
# predicted=30010.537231, expected=33088.000000, error=9 percentage
# predicted=32559.264512, expected=126683.000000, error=74 percentage
# predicted=81122.867737, expected=37684.000000, error=115 percentage
# predicted=61479.034664, expected=37476.000000, error=64 percentage
# predicted=35930.545448, expected=49361.000000, error=27 percentage
# predicted=41668.753249, expected=44583.000000, error=6 percentage
# predicted=38991.515703, expected=44810.000000, error=12 percentage
# predicted=59706.034622, expected=193730.000000, error=69 percentage
# predicted=110122.214530, expected=58363.000000, error=88 percentage
# predicted=79925.676582, expected=43900.000000, error=82 percentage
# predicted=56761.976084, expected=33316.000000, error=70 percentage
# predicted=30303.178856, expected=28668.000000, error=5 percentage
# predicted=25770.352060, expected=104319.000000, error=75 percentage
# predicted=114655.635788, expected=32270.000000, error=255 percentage
# predicted=44448.416116, expected=36751.000000, error=20 percentage
# predicted=32677.746862, expected=35130.000000, error=6 percentage
# predicted=25738.281950, expected=29942.000000, error=14 percentage
# predicted=34467.785350, expected=24907.000000, error=38 percentage
# predicted=43418.415406, expected=24447.000000, error=77 percentage
# predicted=23746.030892, expected=23496.000000, error=1 percentage
# predicted=26046.780261, expected=26116.000000, error=0 percentage
# predicted=27563.766167, expected=33049.000000, error=16 percentage
# predicted=30433.431310, expected=31031.000000, error=1 percentage
# predicted=31009.532169, expected=22641.000000, error=36 percentage
# predicted=28003.900987, expected=22788.000000, error=22 percentage
# predicted=26600.839989, expected=23792.000000, error=11 percentage
# predicted=28343.788884, expected=27438.000000, error=3 percentage
# predicted=31935.093045, expected=36332.000000, error=12 percentage
# predicted=35123.414768, expected=36380.000000, error=3 percentage
# predicted=35292.368174, expected=27365.000000, error=28 percentage
# predicted=32293.114442, expected=26046.000000, error=23 percentage
# predicted=30269.396883, expected=25078.000000, error=20 percentage
# predicted=30763.090181, expected=27744.000000, error=10 percentage
# predicted=33754.094585, expected=34269.000000, error=1 percentage
# predicted=35768.003789, expected=34160.000000, error=4 percentage
# predicted=34837.623212, expected=25434.000000, error=36 percentage
# predicted=31196.444432, expected=24536.000000, error=27 percentage
# predicted=28971.864566, expected=24344.000000, error=19 percentage
# predicted=29590.128811, expected=26040.000000, error=13 percentage
# predicted=31948.200306, expected=29648.000000, error=7 percentage
# predicted=32750.166336, expected=36833.000000, error=11 percentage
# predicted=34448.043581, expected=35244.000000, error=2 percentage
# predicted=35427.631614, expected=26938.000000, error=31 percentage
# predicted=32124.269586, expected=26752.000000, error=20 percentage
# predicted=30776.590161, expected=34827.000000, error=11 percentage
# predicted=35168.091169, expected=38221.000000, error=7 percentage
# predicted=39765.142357, expected=37640.000000, error=5 percentage
# predicted=39044.324823, expected=28899.000000, error=35 percentage
# predicted=33021.743279, expected=29428.000000, error=12 percentage
# predicted=32167.244283, expected=28289.000000, error=13 percentage
# predicted=33566.172370, expected=28032.000000, error=19 percentage
# predicted=33973.015384, expected=31199.000000, error=8 percentage
# predicted=33947.553149, expected=37843.000000, error=10 percentage
# predicted=35398.624586, expected=36665.000000, error=3 percentage
# predicted=36731.112656, expected=28729.000000, error=27 percentage
# predicted=33240.294630, expected=28265.000000, error=17 percentage
# predicted=31479.141085, expected=27525.000000, error=14 percentage
# predicted=32101.934564, expected=27547.000000, error=16 percentage
# predicted=33498.312625, expected=31044.000000, error=7 percentage
# predicted=33655.946437, expected=39459.000000, error=14 percentage
# predicted=36020.927868, expected=37758.000000, error=4 percentage
# predicted=37283.272196, expected=28619.000000, error=30 percentage
# predicted=33374.177335, expected=27003.000000, error=23 percentage
# predicted=30868.823676, expected=24980.000000, error=23 percentage
# predicted=30886.483216, expected=25947.000000, error=19 percentage
# predicted=32729.538354, expected=28458.000000, error=15 percentage
# predicted=32339.233613, expected=35413.000000, error=8 percentage
# predicted=33605.917990, expected=34846.000000, error=3 percentage
# predicted=34656.312781, expected=27653.000000, error=25 percentage
# predicted=31659.621609, expected=27162.000000, error=16 percentage
# predicted=30383.934984, expected=26462.000000, error=14 percentage
# predicted=30936.706824, expected=27930.000000, error=10 percentage
# predicted=33088.919065, expected=32851.000000, error=0 percentage
# predicted=34348.583636, expected=33380.000000, error=2 percentage
# predicted=33865.231208, expected=34399.000000, error=1 percentage
# predicted=34616.001299, expected=29545.000000, error=17 percentage
# predicted=32720.405816, expected=27964.000000, error=17 percentage
# predicted=31948.946679, expected=26599.000000, error=20 percentage
# predicted=31886.999704, expected=28026.000000, error=13 percentage
# predicted=32294.202407, expected=29396.000000, error=9 percentage
# predicted=32790.098958, expected=34933.000000, error=6 percentage
# predicted=34189.318447, expected=33635.000000, error=1 percentage
# predicted=34443.272173, expected=27857.000000, error=23 percentage
# predicted=31921.028806, expected=33734.000000, error=5 percentage
# predicted=33529.416469, expected=34734.000000, error=3 percentage
# predicted=35713.417982, expected=32619.000000, error=9 percentage
# predicted=36541.403152, expected=34368.000000, error=6 percentage
# predicted=35552.414080, expected=42317.000000, error=15 percentage
# predicted=38210.744834, expected=42639.000000, error=10 percentage
# predicted=41622.402085, expected=31889.000000, error=30 percentage
# predicted=37260.395905, expected=31437.000000, error=18 percentage
# predicted=34074.751197, expected=30281.000000, error=12 percentage
# predicted=33992.623937, expected=37432.000000, error=9 percentage
# predicted=38822.770913, expected=36345.000000, error=6 percentage
# predicted=38463.983105, expected=28597.000000, error=34 percentage
# predicted=32692.478249, expected=30255.000000, error=8 percentage
# predicted=31644.623458, expected=27695.000000, error=14 percentage
# predicted=31203.416647, expected=29162.000000, error=7 percentage
# predicted=33376.613329, expected=33419.000000, error=0 percentage
# predicted=34208.681029, expected=39667.000000, error=13 percentage
# predicted=36301.934850, expected=38784.000000, error=6 percentage
# predicted=37802.430744, expected=29740.000000, error=27 percentage
# predicted=33614.733744, expected=27200.000000, error=23 percentage
# predicted=31303.756439, expected=27013.000000, error=15 percentage
# predicted=31835.155552, expected=28057.000000, error=13 percentage
# predicted=33583.093003, expected=31248.000000, error=7 percentage
# predicted=33871.510324, expected=70434.000000, error=51 percentage
# predicted=48795.051031, expected=34455.000000, error=41 percentage
# predicted=41268.762152, expected=31683.000000, error=30 percentage
# predicted=34833.357706, expected=30600.000000, error=13 percentage
# predicted=31217.987143, expected=32070.000000, error=2 percentage
# predicted=37000.669924, expected=33327.000000, error=11 percentage
# predicted=43211.155250, expected=37710.000000, error=14 percentage
# predicted=35356.264548, expected=37531.000000, error=5 percentage
# predicted=35941.396526, expected=31999.000000, error=12 percentage
# predicted=34065.340559, expected=31450.000000, error=8 percentage
# predicted=33327.733821, expected=31965.000000, error=4 percentage
# predicted=33995.830237, expected=34512.000000, error=1 percentage
# predicted=36346.237787, expected=37833.000000, error=3 percentage
# predicted=37612.546128, expected=41020.000000, error=8 percentage
# predicted=38357.760077, expected=41455.000000, error=7 percentage
# predicted=39335.899042, expected=36471.000000, error=7 percentage
# predicted=37791.564361, expected=34444.000000, error=9 percentage
# predicted=36711.555273, expected=44392.000000, error=17 percentage
# predicted=41128.187047, expected=31403.000000, error=30 percentage
# predicted=38227.660488, expected=31269.000000, error=22 percentage
# predicted=35475.663961, expected=34450.000000, error=2 percentage
# predicted=34334.429262, expected=33887.000000, error=1 percentage
# predicted=35749.021419, expected=29786.000000, error=20 percentage
# predicted=35311.566262, expected=31362.000000, error=12 percentage
# predicted=31845.866320, expected=31764.000000, error=0 percentage
